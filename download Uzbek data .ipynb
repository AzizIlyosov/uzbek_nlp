# %%
import requests
p = requests.get()

# %%
headers = {'Accept-Encoding': 'identity', 'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36'}
r = requests.get('https://kun.uz/uz/news/category/uzbekiston', headers=headers)

# %%
dict(r.headers)
# Out:
# {'Server': 'nginx/1.20.1',
#  'Date': 'Mon, 09 Aug 2021 16:51:13 GMT',
#  'Content-Type': 'text/html; charset=UTF-8',
#  'Transfer-Encoding': 'chunked',
#  'Connection': 'keep-alive',
#  'X-Powered-By': 'PHP/7.2.34',
#  'Set-Cookie': '_csrf=5cd7578820cbd12609f80d08e0477c55dc3de85aa7f9c196469ede1b7c36a572a%3A2%3A%7Bi%3A0%3Bs%3A5%3A%22_csrf%22%3Bi%3A1%3Bs%3A32%3A%22dZDDh0Bc4S-6nUXrafX-wzQOFUle1BAL%22%3B%7D; path=/; HttpOnly'}

# %%
# from bs4 import BeautifulSoup
# from urllib.request import urlopen
# for i in range(100000):
#     with urlopen('https://kun.uz/uz/news/category/uzbekiston') as response:
#         soup = BeautifulSoup(response, 'html.parser')
#         print(len(soup.find_all('a')))
        
    
# #     for anchor in soup.find_all('a'):
        
        
# #         with urlopen(anchor) as response2:
# #             soup2 = BeautifulSoup(response2, 'html.parser') 
# #             for anchor2 in soup2.find_all('a'):
# #                 print(anchor2.get('href', '/'))

# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
# for i in range(100000):
base_path ='https://kun.uz/uz'
hist = [] 
with urlopen(base_path) as response:
    print('done')
    soup = BeautifulSoup(response, 'html.parser')
    all_links = soup.find_all('a',{'href': True})
    for link in all_links:   
        second_level = urllib.parse.urljoin(base_path, link['href'])
        print(second_level)
        if base_path in second_level:
            with urlopen(second_level)  as s_l:
                soup2 = BeautifulSoup(s_l, 'html.parser')
                all_links = soup2.find_all('a',{'href': True})
                for l in all_links:  
                    l = urllib.parse.urljoin(base_path, l['href'])
                    if not l in hist and base_path in l: 
                        hist.append(l)
                        with urlopen(l) as p :
                            print('done')
#                             b = BeautifulSoup(p, 'html.parser')
#                             print('all links .. ', len(b.find_all('a')))
# Out:
# done
# <a class="advertisement advertisement_top-bar" href="/uz/ad/3367" target="__BLANK"><img src="https://storage.kun.uz/source/7/nm53HygU-lx-Lwra-Ua_B6NgRuz8rl0a.png" style="max-height: 100% !important;"/></a>
# https://kun.uz/uz/ad/3367
# done
# done
# <a class="page-header__logo" href="/uz"><img alt="Logo" src="/assets/4da8d774/img/kun-uz-logo.svg"/></a>
# https://kun.uz/uz
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# <a class="menu-link" href="/uz/news/category/uzbekiston">O‘zbekiston</a>
# https://kun.uz/uz/news/category/uzbekiston
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...
